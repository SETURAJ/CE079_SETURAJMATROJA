# %% [markdown]
# Mounting Drive and Importing Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np 
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import seaborn as sns

# %% [markdown]
# LOAD DATA

# %%
data=pd.read_csv('drive/MyDrive/Exercise-CarData.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  Price   Age     KM  ... Automatic    CC  Doors  Weight
# 0           0  13500  23.0  46986  ...         0  2000  three    1165
# 1           1  13750  23.0  72937  ...         0  2000      3    1165
# 2           2  13950  24.0  41711  ...         0  2000      3    1165
# 3           3  14950  26.0  48000  ...         0  2000      3    1165
# 4           4  13750  30.0  38500  ...         0  2000      3    1170
#
# [5 rows x 11 columns]

# %%
data.tail()
# Out:
#       Unnamed: 0  Price   Age     KM  ... Automatic    CC  Doors  Weight
# 1431        1431   7500   NaN  20544  ...         0  1300      3    1025
# 1432        1432  10845  72.0     ??  ...         0  1300      3    1015
# 1433        1433   8500   NaN  17016  ...         0  1300      3    1015
# 1434        1434   7250  70.0     ??  ...         0  1300      3    1015
# 1435        1435   6950  76.0      1  ...         0  1600      5    1114
#
# [5 rows x 11 columns]

# %%
data
# Out:
#       Unnamed: 0  Price   Age     KM  ... Automatic    CC  Doors  Weight
# 0              0  13500  23.0  46986  ...         0  2000  three    1165
# 1              1  13750  23.0  72937  ...         0  2000      3    1165
# 2              2  13950  24.0  41711  ...         0  2000      3    1165
# 3              3  14950  26.0  48000  ...         0  2000      3    1165
# 4              4  13750  30.0  38500  ...         0  2000      3    1170
# ...          ...    ...   ...    ...  ...       ...   ...    ...     ...
# 1431        1431   7500   NaN  20544  ...         0  1300      3    1025
# 1432        1432  10845  72.0     ??  ...         0  1300      3    1015
# 1433        1433   8500   NaN  17016  ...         0  1300      3    1015
# 1434        1434   7250  70.0     ??  ...         0  1300      3    1015
# 1435        1435   6950  76.0      1  ...         0  1600      5    1114
#
# [1436 rows x 11 columns]

# %% [markdown]
# Find the missing values and handle it by Imputation

# %%
df=data;
df['KM'].replace(to_replace="??",value=np.NaN,inplace=True)
df['HP'].replace(to_replace="????",value=np.NaN,inplace=True)
df
# Out:
#       CNG  Diesel  Petrol  Unnamed: 0  ...  Automatic      CC  Doors  Weight
# 0       0       1       0           0  ...          0  2000.0      4    1165
# 1       0       1       0           1  ...          0  2000.0      3    1165
# 2       0       1       0           2  ...          0  2000.0      3    1165
# 3       0       1       0           3  ...          0  2000.0      3    1165
# 4       0       1       0           4  ...          0  2000.0      3    1170
# ...   ...     ...     ...         ...  ...        ...     ...    ...     ...
# 1431    0       0       1        1431  ...          0  1300.0      3    1025
# 1432    0       0       1        1432  ...          0  1300.0      3    1015
# 1433    0       0       1        1433  ...          0  1300.0      3    1015
# 1434    0       0       0        1434  ...          0  1300.0      3    1015
# 1435    0       0       1        1435  ...          0  1600.0      5    1114
#
# [1436 rows x 13 columns]

# %%
df['Price'] = pd.to_numeric(df.Price.astype(str).str.replace(',',''), errors='coerce')
df['Price'] = df['Price'].fillna(df['Price'].mean())
df['Age']=df['Age'].fillna(df['Age'].mean())
df['HP'] = pd.to_numeric(df.HP.astype(str).str.replace(',',''), errors='coerce').fillna(90).astype(int)

df['MetColor'] = pd.to_numeric(df.MetColor.astype(str).str.replace(',',''), errors='coerce').fillna(1).astype(int)

df['Automatic'] = pd.to_numeric(df.Automatic.astype(str).str.replace(',',''), errors='coerce').fillna(0).astype(int)

df['Doors'] = pd.to_numeric(df.Doors.astype(str).str.replace(',',''), errors='coerce').fillna(4).astype(int)

df['Weight'] = pd.to_numeric(df.Weight.astype(str).str.replace(',',''), errors='coerce')
df['Weight'] = df['Weight'].fillna(df['Weight'].mean())
df
# Out:
#       CNG  Diesel  Petrol  Unnamed: 0  ...  Automatic      CC  Doors  Weight
# 0       0       1       0           0  ...          0  2000.0      4    1165
# 1       0       1       0           1  ...          0  2000.0      3    1165
# 2       0       1       0           2  ...          0  2000.0      3    1165
# 3       0       1       0           3  ...          0  2000.0      3    1165
# 4       0       1       0           4  ...          0  2000.0      3    1170
# ...   ...     ...     ...         ...  ...        ...     ...    ...     ...
# 1431    0       0       1        1431  ...          0  1300.0      3    1025
# 1432    0       0       1        1432  ...          0  1300.0      3    1015
# 1433    0       0       1        1433  ...          0  1300.0      3    1015
# 1434    0       0       0        1434  ...          0  1300.0      3    1015
# 1435    0       0       1        1435  ...          0  1600.0      5    1114
#
# [1436 rows x 13 columns]

# %%
df['KM']=df['KM'].astype(float)
updated_data=df;
updated_data['KM']=updated_data['KM'].fillna(updated_data['KM'].mean())
print(updated_data)
# Out:
#       CNG  Diesel  Petrol  Unnamed: 0  ...  Automatic      CC  Doors  Weight
# 0       0       1       0           0  ...          0  2000.0      4    1165
# 1       0       1       0           1  ...          0  2000.0      3    1165
# 2       0       1       0           2  ...          0  2000.0      3    1165
# 3       0       1       0           3  ...          0  2000.0      3    1165
# 4       0       1       0           4  ...          0  2000.0      3    1170
# ...   ...     ...     ...         ...  ...        ...     ...    ...     ...
# 1431    0       0       1        1431  ...          0  1300.0      3    1025
# 1432    0       0       1        1432  ...          0  1300.0      3    1015
# 1433    0       0       1        1433  ...          0  1300.0      3    1015
# 1434    0       0       0        1434  ...          0  1300.0      3    1015
# 1435    0       0       1        1435  ...          0  1600.0      5    1114
#
# [1436 rows x 13 columns]

# %%
df['CC']=df['CC'].astype(float)
updated_data=df;
updated_data['CC']=updated_data['CC'].fillna(updated_data['CC'].mean())
print(updated_data)
# Out:
#       CNG  Diesel  Petrol  Unnamed: 0  ...  Automatic      CC  Doors  Weight
# 0       0       1       0           0  ...          0  2000.0      4    1165
# 1       0       1       0           1  ...          0  2000.0      3    1165
# 2       0       1       0           2  ...          0  2000.0      3    1165
# 3       0       1       0           3  ...          0  2000.0      3    1165
# 4       0       1       0           4  ...          0  2000.0      3    1170
# ...   ...     ...     ...         ...  ...        ...     ...    ...     ...
# 1431    0       0       1        1431  ...          0  1300.0      3    1025
# 1432    0       0       1        1432  ...          0  1300.0      3    1015
# 1433    0       0       1        1433  ...          0  1300.0      3    1015
# 1434    0       0       0        1434  ...          0  1300.0      3    1015
# 1435    0       0       1        1435  ...          0  1600.0      5    1114
#
# [1436 rows x 13 columns]

# %% [markdown]
# Seperate Input and Output attributes

# %%
X = data.loc[:,data.columns != "Price"]

Y = data["Price"].values

X_new = X.iloc[:,1:].values
X = X.values
X_new
# Out:
# array([[1.000e+00, 0.000e+00, 0.000e+00, ..., 2.000e+03, 4.000e+00,
#         1.165e+03],
#        [1.000e+00, 0.000e+00, 1.000e+00, ..., 2.000e+03, 3.000e+00,
#         1.165e+03],
#        [1.000e+00, 0.000e+00, 2.000e+00, ..., 2.000e+03, 3.000e+00,
#         1.165e+03],
#        ...,
#        [0.000e+00, 1.000e+00, 1.433e+03, ..., 1.300e+03, 3.000e+00,
#         1.015e+03],
#        [0.000e+00, 0.000e+00, 1.434e+03, ..., 1.300e+03, 3.000e+00,
#         1.015e+03],
#        [0.000e+00, 1.000e+00, 1.435e+03, ..., 1.600e+03, 5.000e+00,
#         1.114e+03]])

# %% [markdown]
# Perform scaling (Min-Max Normalization)

# %%
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X_new)
print("\n\nScaled X : \n", X_scaled)
# Out:
# Scaled X :
#  [[1.00000000e+00 0.00000000e+00 0.00000000e+00 ... 1.00000000e+00
#   6.66666667e-01 2.68292683e-01]
#  [1.00000000e+00 0.00000000e+00 6.96864111e-04 ... 1.00000000e+00
#   3.33333333e-01 2.68292683e-01]
#  [1.00000000e+00 0.00000000e+00 1.39372822e-03 ... 1.00000000e+00
#   3.33333333e-01 2.68292683e-01]
#  ...
#  [0.00000000e+00 1.00000000e+00 9.98606272e-01 ... 0.00000000e+00
#   3.33333333e-01 2.43902439e-02]
#  [0.00000000e+00 0.00000000e+00 9.99303136e-01 ... 0.00000000e+00
#   3.33333333e-01 2.43902439e-02]
#  [0.00000000e+00 1.00000000e+00 1.00000000e+00 ... 4.28571429e-01
#   1.00000000e+00 1.85365854e-01]]

# %% [markdown]
# Perform Standardization

# %%
std = StandardScaler()
X_std = std.fit_transform(X_new)
print(X_std)
# Out:
# [[ 2.99536679 -2.1317602  -1.73084506 ...  2.31497633 -0.0351258
#    1.75856113]
#  [ 2.99536679 -2.1317602  -1.72843274 ...  2.31497633 -1.08597279
#    1.75856113]
#  [ 2.99536679 -2.1317602  -1.72602041 ...  2.31497633 -1.08597279
#    1.75856113]
#  ...
#  [-0.33384893  0.46909591  1.72602041 ... -1.42599356 -1.08597279
#   -1.09191497]
#  [-0.33384893 -2.1317602   1.72843274 ... -1.42599356 -1.08597279
#   -1.09191497]
#  [-0.33384893  0.46909591  1.73084506 ...  0.17727925  1.01572118
#    0.78939926]]

# %% [markdown]
# Selecting features based on correlation

# %% [markdown]
# Generating the correlation matrix

# %%
corr = df.corr()
corr.head()
# Out:
#                  CNG    Diesel    Petrol  ...        CC     Doors    Weight
# CNG         1.000000 -0.034300 -0.219022  ...  0.018141  0.017984  0.051688
# Diesel     -0.034300  1.000000 -0.711686  ...  0.730292  0.012636  0.516471
# Petrol     -0.219022 -0.711686  1.000000  ... -0.561913 -0.010168 -0.425511
# Unnamed: 0 -0.043811 -0.139813  0.124362  ... -0.184490 -0.130940 -0.414577
# Price      -0.032498  0.014590 -0.024046  ...  0.165067  0.185579  0.581198
#
# [5 rows x 13 columns]

# %% [markdown]
# Generating the correlation heatmap

# %%
sns.heatmap(corr)

# %% [markdown]
# Next, we compare the correlation between features and remove one of two features that have a correlation higher than 0.9

# %%
columns = np.full((corr.shape[0],), True, dtype=bool)
for i in range(corr.shape[0]):
    for j in range(i+1, corr.shape[0]):
        if corr.iloc[i,j] >= 0.9:
            if columns[j]:
                columns[j] = False

# %%
selected_columns = df.columns[columns]
selected_columns.shape
# Out:
# (13,)

# %%
df = df[selected_columns]
df
# Out:
#       CNG  Diesel  Petrol  Unnamed: 0  ...  Automatic      CC  Doors  Weight
# 0       0       1       0           0  ...          0  2000.0      4    1165
# 1       0       1       0           1  ...          0  2000.0      3    1165
# 2       0       1       0           2  ...          0  2000.0      3    1165
# 3       0       1       0           3  ...          0  2000.0      3    1165
# 4       0       1       0           4  ...          0  2000.0      3    1170
# ...   ...     ...     ...         ...  ...        ...     ...    ...     ...
# 1431    0       0       1        1431  ...          0  1300.0      3    1025
# 1432    0       0       1        1432  ...          0  1300.0      3    1015
# 1433    0       0       1        1433  ...          0  1300.0      3    1015
# 1434    0       0       0        1434  ...          0  1300.0      3    1015
# 1435    0       0       1        1435  ...          0  1600.0      5    1114
#
# [1436 rows x 13 columns]
